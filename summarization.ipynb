# %% [markdown]
# <a href="https://colab.research.google.com/github/shobithkumar1994/shobithh/blob/main/summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
article_text = "This is the text you want to clean. It may contain spaces"

# %%
# Import regex module and nltk
import re
import nltk
from nltk.tokenize import word_tokenize

# %%
# Cleaning the text by removing numbers and special characters
clean_text = re.sub('[^a-zA-Z]', ' ', article_text)
print(clean_text)
# Out:
# This is the text you want to clean  It may contain spaces

# %%
# Convert the cleaned text to lowercase article_text = article_text.lower()
print(article_text)
# Out:
# This is the text you want to clean. It may contain spaces

# %%
# Download required nltk data (if necessary)nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Tokenize the article text into sentences
sentence_list = nltk.sent_tokenize(clean_text)
print(sentence_list)
# Out:
# ['This is the text you want to clean  It may contain spaces']

# %%
# Tokenize the article text into words
tokens = word_tokenize(article_text)
print(tokens)
# Out:
# ['This', 'is', 'the', 'text', 'you', 'want', 'to', 'clean', '.', 'It', 'may', 'contain', 'spaces']

# %%
# Import stopwords and download them
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Import stopwords and download them
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')

# Create a dictionary to store word frequencies, ignoring stopwords
word_frequencies = {}
for word in tokens:
    if word not in stopwords:
        if word not in word_frequencies:
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# Print word frequencies
print(word_frequencies)
# Out:
# {'This': 1, 'text': 1, 'want': 1, 'clean': 1, '.': 1, 'It': 1, 'may': 1, 'contain': 1, 'spaces': 1}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Import string module for removing punctuation and digits
import string
from nltk.probability import FreqDist

# Remove punctuation and digits from stopwords list
remove_these = set(stopwords + list(string.punctuation) + list(string.digits))

# Create frequency distribution of the words
word_freq = FreqDist(word_frequencies)
print(word_freq)
# Out:
# <FreqDist with 9 samples and 9 outcomes>

# %%
# Plot the frequency distribution using word frequencies
word_freq.plot(10, title="freqplot")
# Out:
# <Axes: title={'center': 'freqplot'}, xlabel='Samples', ylabel='Counts'>

# %%
# Import Counter from collections for counting frequencies
from collections import Counter

# Count the word frequencies
dictionary_counter = Counter(word_frequencies)
print(dictionary_counter)
# Out:
# Counter({'This': 1, 'text': 1, 'want': 1, 'clean': 1, '.': 1, 'It': 1, 'may': 1, 'contain': 1, 'spaces': 1})

# %%
# Step to install the wordcloud module (only required if not already installed)
#!pip install wordcloud(Do only if necessary)

# Import necessary libraries for word cloud generation
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Generate a word cloud based on word frequencies
cloud = WordCloud(max_font_size=80, colormap='hsv').generate_from_frequencies(dictionary_counter)

# Plot the word cloud
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()
